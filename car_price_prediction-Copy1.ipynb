# %%
import pandas as pd

# %%
data=pd.read_csv('car data.csv')

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.shape
# Out:
# (301, 9)

# %%
import datetime

# %%
date_time=datetime.datetime.now()

# %%
data['Age']=date_time.year-data['Year']

# %%
data=data.drop('Year',axis=1)

# %%
data=data.drop('Car_Name',axis=1)

# %%
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# 3         Manual      0   13
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(x=data['Selling_Price'])
# Out:
# <Axes: xlabel='Selling_Price'>

# %%
data=data[~(data['Selling_Price']>=33) & (data['Selling_Price']<=35)]

# %%
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# 3         Manual      0   13
# ...

# %%
data['Fuel_Type']=data['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':3})

# %%
data['Seller_Type']=data['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          0            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          0            0
# 3             2.85           4.15        5200          0            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          0            0
# 298           3.35          11.00       87934          0            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          0            0
#
#     Transmission  Owner  Age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# ...

# %%
data.isnull().sum()
# Out:
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Age              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Selling_Price  299 non-null    float64
#  1   Present_Price  299 non-null    float64
#  2   Kms_Driven     299 non-null    int64
#  3   Fuel_Type      299 non-null    int64
#  4   Seller_Type    299 non-null    int64
#  5   Transmission   299 non-null    object
#  6   Owner          299 non-null    int64
#  7   Age            299 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 21.0+ KB

# %%
data['Transmission']=data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred1=lr.predict(x_test)
y_pred2=rf.predict(x_test)
y_pred3=gbr.predict(x_test)
y_pred4=xgb.predict(x_test)

# %%
from sklearn import metrics

# %%
score1=metrics.r2_score(y_test,y_pred1)
score2=metrics.r2_score(y_test,y_pred2)
score3=metrics.r2_score(y_test,y_pred3)
score4=metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.6729173865305433 0.7229884005927412 0.8953133823494465 0.8887471822279068

# %%
final=pd.DataFrame({'model':['LR','RF','GBR','XGB'],'r2_score':[score1,score2,score3,score4]})

# %%
final
# Out:
#   model  r2_score
# 0    LR  0.672917
# 1    RF  0.722988
# 2   GBR  0.895313
# 3   XGB  0.888747

# %%
gbr=GradientBoostingRegressor()
gbr_final=gbr.fit(x,y)

# %%
import joblib

# %%
joblib.dump(gbr,'car_price_prediction')
# Out:
# ['car_price_prediction']

# %%
model=joblib.load('car_price_prediction')

# %%
import pandas as pd

# %%
data_new=pd.DataFrame({
    'Present_Price':6,
    'Kms_Driven':27000,
    'Fuel_Type':0,
    'Seller_Type':0,
    'Transmission':0,
    'Owner':0,
    'Age':8
    
    
},index=[0])

# %%
data_new
# Out:
#    Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  Age
# 0              6       27000          0            0             0      0    8

# %%
model.predict(data_new)
# Out:
# array([5.05946597])

# %%
from tkinter import *
import joblib
import pandas

# %%
def show_entry():
    p1=float(e1.get())
    p2=float(e2.get())   
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    
    
    model=joblib.load('car_price_prediction')
    result=model.predict([[p1,p2,p3,p4,p5,p6,p7]])
    Label(master,text="price prediction").grid(row=8)
    Label(master,text=result).grid(row=9)



master=Tk()
master.title("car_price_prediction")
label=Label(master,text="car_price_prediction",bg="black",fg="white").grid(row=0,columnspan=2)

Label(master,text="Enter present price").grid(row=1)
Label(master,text="Enter kms driven").grid(row=2)
Label(master,text="Enter fuel type").grid(row=3)
Label(master,text="Enter seller type").grid(row=4)
Label(master,text="Enter transmission").grid(row=5)
Label(master,text="Enter owner type").grid(row=6)
Label(master,text="Enter age of car").grid(row=7)

e1=Entry(master)
e2=Entry(master)
e3=Entry(master)
e4=Entry(master)
e5=Entry(master)
e6=Entry(master)
e7=Entry(master)

e1.grid(row=1,column=1)
e2.grid(row=2,column=1)
e3.grid(row=3,column=1)
e4.grid(row=4,column=1)
e5.grid(row=5,column=1)
e6.grid(row=6,column=1)
e7.grid(row=7,column=1)

Button(master,text="predict",command=show_entry).grid()

mainloop()
